# %%
import pandas as pd

# %%
train_data = pd.read_csv('big_train.csv', index_col = 'client_id')

# %%
train_data.head()
# Out:
#                  sum  count  small_group_count0  small_group_count1  \
# client_id
# 4          28404.121    720                 0.0               447.0
# 6          15720.739    730                 2.0               397.0
# 7          53630.036    773                 2.0                79.0
# 10         34419.365    706                12.0               309.0
# 11         26789.404    812                 2.0               423.0
#
#            small_group_count2  small_group_count3  small_group_count4  \
# client_id
# 4                         1.0                44.0                93.0
# 6                         0.0               172.0                10.0
# 7                         5.0                27.0                19.0
# 10                        1.0                71.0                65.0
# 11                        0.0                59.0                23.0
#
#            small_group_count5  small_group_count6  small_group_count7  ...   \
# ...
